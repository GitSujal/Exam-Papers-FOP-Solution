# %%
import random
biscuits = []
biscuits.extend(['Monte Carlo']*7)
biscuits.extend(['Shortbread Cream']*2)
biscuits.extend(['Delta Cream']*3)
biscuits.extend(['Orange Slice']*5)
biscuits.extend(['Kingston']*9)
print('\nASSORTED CREAMS\n')
more = input('\nWould you like a biscuit (Y/N)... ')
while more.upper() != 'N' and len(biscuits)>=0:
    number = input("How many biscuits would you like: ")
    if number.isnumeric():
        number = int(number)
        if len(biscuits)>=number:
            for i in range(number): 
                choice = random.randint(0,len(biscuits)-1)
                print('Your biscuit is : ', biscuits[choice])
                del biscuits[choice]
            print("Remaining Biscuits: ",biscuits,"\n")
        else: 
            print("Not enough biscuits.")
    else:
        print("Invalid number of biscuit provided")
     
    more = input('\nWould you like another biscuit (Y/N)...')

print("Exiting program")
# Out:
# ASSORTED CREAMS
#
#
# Would you like a biscuit (Y/N)... y
# How many biscuits would you like: 8
# Your biscuit is :  Monte Carlo
# Your biscuit is :  Kingston
# Your biscuit is :  Kingston
# Your biscuit is :  Monte Carlo
# Your biscuit is :  Kingston
# Your biscuit is :  Kingston
# Your biscuit is :  Orange Slice
# Your biscuit is :  Monte Carlo
# Remaining Biscuits:  ['Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Shortbread Cream', 'Shortbread Cream', 'Delta Cream', 'Delta Cream', 'Delta Cream', 'Orange Slice', 'Orange Slice', 'Orange Slice', 'Orange Slice', 'Kingston', 'Kingston', 'Kingston', 'Kingston', 'Kingston']
#
#
# Would you like another biscuit (Y/N)...y
# How many biscuits would you like: 5
# Your biscuit is :  Kingston
# Your biscuit is :  Orange Slice
# Your biscuit is :  Delta Cream
# Your biscuit is :  Shortbread Cream
# Your biscuit is :  Orange Slice
# Remaining Biscuits:  ['Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Shortbread Cream', 'Delta Cream', 'Delta Cream', 'Orange Slice', 'Orange Slice', 'Kingston', 'Kingston', 'Kingston', 'Kingston']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/lib/python3/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c353f7078284> in <module>()
#      23         print("Invalid number of biscuit provided")
#      24
# ---> 25     more = input('\nWould you like another biscuit (Y/N)...')
#      26
#      27 print("Exiting program")
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
punctuation = '~!@#$%^&*()_+{}|:"<>?`=[]\\;\',./'
#Read from the file: MeaningOfLife.txt.
filename = 'grimm.txt'
book = open(filename).read()
bookNoPunct = book.translate(str.maketrans('','',punctuation))
# Ignore case (upper/lower) when counting words.
words = bookNoPunct.lower().split()
print(words)
wordfreq = {}
for word in words:
    # Ignore numbers when counting words.
    if not word.isnumeric():
        if word not in wordfreq:
            wordfreq[word] = 0
        wordfreq[word] += 1

total =0
for keys in wordfreq.keys():
    print(keys, ": ",wordfreq[keys])
    total+=wordfreq[keys]

# for values in wordfreq.values():
#     total+= values
    
print("Total unique words = ",len(wordfreq))
print("Total words =",total)
# Out:
# ['sujal', 'sujal', 'sujal', 'sujal', 'aslfk', 'sdlf', 'm', 'zxfs', 'fasfdmaslfd', 'jmasl', 'daslkf', 'vmzkfx', 'vlwvsdfkdadsldvv', 'czlzfmcskzdkvmbkvzkjdmbvtkbsvjdtmlbd', 'lks', 'efmselibnmdtl']
# sujal :  4
# aslfk :  1
# sdlf :  1
# m :  1
# zxfs :  1
# fasfdmaslfd :  1
# jmasl :  1
# daslkf :  1
# vmzkfx :  1
# vlwvsdfkdadsldvv :  1
# czlzfmcskzdkvmbkvzkjdmbvtkbsvjdtmlbd :  1
# lks :  1
# efmselibnmdtl :  1
# Total unique words =  13
# Total words = 16

# %%
import re
phoneRegex = re.compile(r'''(
(\(?\d{3}\-?\d{3}\)?)
(\s|\-)
(\d{6,9} | \d{3,4}\-\d{4})
)''', re.VERBOSE)
fileobj = open('accounts.txt')
data = fileobj.readlines()
count=0
for number in data:
    number = number.strip()
    mo = phoneRegex.search(number)
    if mo:
        count+=1
        print(number + ' found ' + mo.group())
print(count)
# Out:
# 066-016-3345243 found 066-016-3345243
# (066016) 3345243 found (066016) 3345243
# 066-016 3345243 found 066-016 3345243
# (066-016) 3345243 found (066-016) 3345243
# 066-016-334-5243 found 066-016-334-5243
# (066016) 33452435 found (066016) 33452435
# (066016)-33452435 found (066016)-33452435
# 306-065-123456789 found 306-065-123456789
# (306065) 12345678 found (306065) 12345678
# 306-065 12345678 found 306-065 12345678
# (306-065) 12345678 found (306-065) 12345678
# 306-065-1234-5243 found 306-065-1234-5243
# (306065) 123458 found (306065) 123458
# (306065)-123458 found (306065)-123458
# 14

# %%
# Given a list of strings in templist, convert each to a floating point number:
templist = ['37.4', '34.3', '28.4', '29.0']
float_temp = [float(element) for element in templist]
print(float_temp)
# Out:
# [37.4, 34.3, 28.4, 29.0]

# %%
#Write code to create a new list "initials", containing the first letter of each word in a list of words (wordlist), converted to uppercase:
wordlist = ['fundamentals', 'of', 'programming']

initials = [words[0].upper() for words in wordlist]
print(initials)
# Out:
# ['F', 'O', 'P']

# %%
#Create a new list called "newlist" out of the list "numbers", which contains only the even numbers from the list, as integers
numbers = [25, 76, -1, -23, 12,-22]

evens = [number for number in numbers if number%2==0 and number>0]
print(evens)
# Out:
# [76, 12]

# %%
import matplotlib.pyplot as plt
from scipy import ndimage
from scipy import misc
# %matplotlib inline
face = misc.face(gray=True)
plt.imshow(face, cmap=plt.cm.Greys_r)

# %%
cropped_face = face[50:-50,20:-20]
plt.imshow(cropped_face, cmap=plt.cm.Blues_r)

cropped_pixelated = cropped_face[::20,::20]
#plt.imshow(cropped_pixelated, cmap=plt.cm.Purples_r)

# %%
import numpy as np
data = np.zeros((3,2,2))
data[1,0,1] = 4
data[0,1,0] = 8
data[2,1,1] = 12
data = data/2
print(data)
data = data + 10
data.resize(2,7)
print(data)
# Out:
# [[[0. 0.]
#   [4. 0.]]
#
#  [[0. 2.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 6.]]]
# [[10. 10. 14. 10. 10. 12. 10.]
#  [10. 10. 10. 10. 16.  0.  0.]]

# %%
a = np.array([1,2,3,4,5,6,7,8743,324,234,4,234,235,235,235,32,532,5,4325])
print(a.sum())
print(a.summary())
# Out:
# 15166
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-80ee85bb123e> in <module>()
#       1 a = np.array([1,2,3,4,5,6,7,8743,324,234,4,234,235,235,235,32,532,5,4325])
#       2 print(a.sum())
# ----> 3 print(a.summary())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'summary'

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('march4.csv')
print(df.tail())
#print(df.describe())
#plt.figure()
df.plot()
#plt.show()
# Out:
#    Minimum temperature (C)  Maximum temperature (C)  9am Temperature (C)  \
# 1                     22.9                     29.9                 24.1
# 2                     20.3                     35.2                 26.5
# 3                     12.9                     24.9                 16.9
# 4                     12.1                     28.0                 18.6
# 5                      9.6                     29.9                 20.7
#
#    3pm Temperature(C)
# 1                25.1
# 2                32.6
# 3                24.3
# 4                27.5
# 5                29.5

# %%
num_competitors = None
num_judges = 2

def get_score(judges):
    score = 0
    for i in range(judges):
        print("Score from Judge ",i+1)
        score += getScoreFromJudge()
    return float(score/judges)

def getInputInRange(first,last):
    number=-1
    while number < first or number > last:
        try:
            print_statement = "Enter the number in range "+str(first)+"-"+str(last)+"  "
            number = int(input(print_statement))
        except ValueError as error:
            print("Invalid input",error)
    return number

def getScoreFromJudge():
    print("The Judge score is ",end =" ")
    score = getInputInRange(0,10)
    return score

print("Enter the number of Competitors...",end="")
num_competitors = getInputInRange(2,20)
competitors_score = []

for i in range(num_competitors):
    print("\nFor Competitor One ",i+1)
    average_score = get_score(num_judges)
    competitors_score.append(average_score)

print(competitors_score)
# Out:
# Enter the number of Competitors...Enter the number in range 2-20  3
#
# For Competitor One  1
# Score from Judge  1
# The Judge score is  Enter the number in range 0-10  -1
# Enter the number in range 0-10  9
# Score from Judge  2
# The Judge score is  Enter the number in range 0-10  329
# Enter the number in range 0-10  3
#
# For Competitor One  2
# Score from Judge  1
# The Judge score is  Enter the number in range 0-10  2
# Score from Judge  2
# The Judge score is  Enter the number in range 0-10  43
# Enter the number in range 0-10  4
#
# For Competitor One  3
# Score from Judge  1
# The Judge score is  Enter the number in range 0-10  4
# Score from Judge  2
# The Judge score is  Enter the number in range 0-10  3
# [6.0, 3.0, 3.5]

# %%
import sys
from conversions import *

choice = sys.argv[1]
value = input()
    
while value != '':
    
    fvalue = float(value)
    if choice[0] == '1':
        print(cel2fahr(fvalue))
    elif choice[0] == '2':
        print(fahr2cel(fvalue))
    else:
        print('Invalid selection.\n')
    value = input()
    
python3 converter4.py 1 <ctemps.txt >ftemps.txt
# Out:
#   File "<ipython-input-98-d8ec47045ae7>", line 3
#     choice = sys.argv[1]
#     ^
# IndentationError: unexpected indent

# %%
class Shape():
    
    def __init__(self, name, colour, num_sides):
        self.name = name
        self.colour = colour
        self.numSides = num_sides
        
    def __str__(self):
        return self.name + " " + self.colour + " " + str(self.area())
    
    def getSides(self):
        return self.numSides

class Triangle(Shape):
    numSides=3
    def __init__(self,name,colour,base, height):
        super().__init__(name,colour,self.numSides)
        self.base = base
        self.height = height
        
    def area(self):
        return self.base/2 * self.height
    
class Rectangle(Shape):
    numSides=4
    def __init__(self,name,colour,width, height):
        super().__init__(name,colour,self.numSides)
        self.width = width
        self.height = height
        
    def area(self):
        return self.width * self.height

    
new_traingle = Triangle("new_Trai","yellow",5,6)
print(new_traingle)
# Out:
# new_Trai yellow 15.0

# %%
n = None
while n is None:
    try:
        s = input("Enter an integer: ")
        n = int(s)
    except ValueError:
        print(s," is not an integer.")
        print("%s is not an integer." % s)
# Out:
# Enter an integer: df
# df  is not an integer.
# df is not an integer.
